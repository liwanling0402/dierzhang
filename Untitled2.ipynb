# %%
import matplotlib.font_manager as fm
font = fm.FontProperties(fname=r"C:\Windows\Fonts\simhei.ttf")  # 宋体路径示例
plt.title('正弦和余弦函数曲线', fontproperties=font)
plt.xlabel('$x$')
plt.ylabel('$y$', fontproperties=font)
import numpy as np
import matplotlib.pyplot as plt

# 1. 生成数据
x = np.linspace(-np.pi, np.pi, 1000)
sin_x = np.sin(x)
cos_x = np.cos(x)

# 2. 绘制曲线并设置标题、轴标签
plt.plot(x, sin_x, label=r'$\sin(x)$')
plt.plot(x, cos_x, label=r'$\cos(x)$')
plt.title('正弦和余弦函数曲线')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend()

# 3. 设置网格线
plt.grid(color='gray', linestyle='--')

# 4. 设置y轴刻度标签为LaTeX格式
plt.yticks([-1, -0.5, 0, 0.5, 1], [r'$-1$', r'$-\frac{1}{2}$', r'$0$', r'$\frac{1}{2}$', r'$1$'])

plt.show()

# %%
plt.axvline(x=avg_box_office, linestyle='--', dashes=(5, 2, 1, 2), color='red', label=f'平均票房：{avg_box_office:.2f}亿')
plt.axvline(x=avg_box_office, linestyle=':', color='red', label=f'平均票房：{avg_box_office:.2f}亿')
import numpy as np
import matplotlib.pyplot as plt

# 假设习题2中的电影票房数据（单位：亿）
movies = ['哪吒之魔童降世', '流浪地球', '复仇者联盟4', '疯狂的外星人', '飞驰人生', 
          '少年的你', '速度与激情：特别行动', '烈火英雄', '蜘蛛侠：英雄远征', 
          '大黄蜂', '惊奇队长', '我和我的祖国', '中国机长', '攀登者', '地久天长']
box_office = [50.35, 46.86, 42.50, 22.13, 17.16, 
              15.58, 14.18, 13.30, 12.44, 11.38, 
              10.25, 9.77, 9.29, 8.97, 8.16]
bar_width = 0.5

# 2. 计算平均票房
avg_box_office = np.mean(box_office)

# 绘制水平柱状图
y_pos = np.arange(len(movies))
plt.barh(y_pos, box_office, height=bar_width, label='电影票房')

# 3. 添加垂直参考线（平均票房）
plt.axvline(x=avg_box_office, linestyle=':--', color='red', label=f'平均票房：{avg_box_office:.2f}亿')

# 4. 为票房最高的电影添加指向型注释
max_index = np.argmax(box_office)
plt.annotate('年度票房冠军', 
             xy=(box_office[max_index], y_pos[max_index]), 
             xytext=(box_office[max_index]+5, y_pos[max_index]+0.2),
             arrowprops=dict(facecolor='blue', shrink=0.05))

# 设置图表属性
plt.yticks(y_pos, movies)
plt.xlabel('票房（亿）')
plt.title('2019年内地电影票房排行榜')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 23
#      20 plt.barh(y_pos, box_office, height=bar_width, label='电影票房')
#      22 # 3. 添加垂直参考线（平均票房）
# ---> 23 plt.axvline(x=avg_box_office, linestyle=':--', color='red', label=f'平均票房：{avg_box_office:.2f}亿')
#      25 # 4. 为票房最高的电影添加指向型注释
#      26 max_index = np.argmax(box_office)
#
# File D:\miniconda\envs\datavis\Lib\site-packages\matplotlib\pyplot.py:2967, in axvline(x, ymin, ymax, **kwargs)
#    2965 @_copy_docstring_and_deprecators(Axes.axvline)
#    2966 def axvline(x: float = 0, ymin: float = 0, ymax: float = 1, **kwargs) -> Line2D:
# -> 2967     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#
# File D:\miniconda\envs\datavis\Lib\site-packages\matplotlib\axes\_axes.py:891, in Axes.axvline(self, x, ymin, ymax, **kwargs)
#     888 scalex = (xx < xmin) or (xx > xmax)
# ...
